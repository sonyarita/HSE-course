# %% [markdown]
# <a href="https://colab.research.google.com/github/sonyarita/HSE-course/blob/main/Popovicheva_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# чтение данных
df = pd.read_csv('working_df_IA.csv')
df
# Out:
#             Slovoforma             lemma part_of_speech  \
# 0               клубни           клубень              S
# 1                снова             снова            ADV
# 2               собаки            собака              S
# 3                траве             трава              S
# 4                 шуба              шуба              S
# ...                ...               ...            ...
# 5279         площадках          площадка              S
# 5280            унесло           уносить              V
# 5281  несправедливость  несправедливость              S
# 5282           рябчики            рябчик              S
# 5283  несправедливость  несправедливость              S
#
#       letters_in_slovoforma  slogi_slovoforma  rang_frequency_NKRIA  \
# 0                         6                 2                     2
# 1                         5                 2                     5
# 2                         6                 3                     5
# ...

# %%
cols_x = ['part_of_speech', 'letters_in_slovoforma', 'slogi_slovoforma', 'rang_frequency_NKRIA']
col_y = 'IA_DWELL_TIME_%'
df1 = df[cols_x + [col_y]].copy()

df1.head()
# Out:
#   part_of_speech  letters_in_slovoforma  slogi_slovoforma  \
# 0              S                      6                 2
# 1            ADV                      5                 2
# 2              S                      6                 3
# 3              S                      5                 2
# 4              S                      4                 2
#
#    rang_frequency_NKRIA  IA_DWELL_TIME_%
# 0                     2           0.0057
# 1                     5           0.0063
# 2                     5           0.0034
# 3                     4           0.0123
# 4                     3           0.0023

# %%
df1['part_of_speech'].value_counts(dropna=False)
# Out:
# part_of_speech
# S       2266
# V       1322
# A        554
# ADV      520
# P        290
# PART      90
# CON       72
# 5         49
# PR        48
# VP        47
# NUM       26
# Name: count, dtype: int64

# %%
df1 = df1[df1["part_of_speech"] != "5"].copy()
df1["part_of_speech"].value_counts(dropna=False)
# Out:
# part_of_speech
# S       2266
# V       1322
# A        554
# ADV      520
# P        290
# PART      90
# CON       72
# PR        48
# VP        47
# NUM       26
# Name: count, dtype: int64
